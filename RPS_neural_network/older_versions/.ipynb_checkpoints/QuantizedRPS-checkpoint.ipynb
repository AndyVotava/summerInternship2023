# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import tensorflow as tf
from PIL import Image
from tensorflow.keras.utils import image_dataset_from_directory
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from numpy.random import seed

# %%
seed(0)
tf.random.set_seed(0)

# %%
#DEFINE AND AUGMENT TRAIN DATA
train_ds = tf.keras.utils.image_dataset_from_directory(
    './Datasheet_RPS/train',
    labels='inferred',
    label_mode='int',
    class_names=None,
    batch_size=32,
    image_size=(30, 30),
    shuffle=True,
    seed=10,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 2529 files belonging to 3 classes.

# %%
#DEFINE AND AUGMENT VALIDATION DATA
val_ds = tf.keras.utils.image_dataset_from_directory(
    './Datasheet_RPS/valid',
    labels='inferred',
    label_mode='int',
    class_names=None,
    batch_size=32,
    image_size=(30, 30),
    shuffle=True,
    seed=10,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 372 files belonging to 3 classes.

# %%
#NORMALIZATION
normalization_layer = layers.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))

# %%
#CREATE MODEL
model = keras.Sequential()
#model.add(layers.Rescaling(1./255, input_shape=(30, 30, 3)))
model.add(layers.Conv2D(90, 3, activation='relu', input_shape=(30,30,3)))
model.add(layers.MaxPooling2D())
model.add(layers.Conv2D(64, 3, activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Conv2D(32, 3, activation='relu'))
model.add(layers.MaxPooling2D())
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(3))

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning, PruningSummaries

pruning_params = {

    "pruning_schedule": pruning_schedule.PolynomialDecay(
    initial_sparsity = 0,
    final_sparsity = .9,
    begin_step = 0,
    end_step = 700,
    power=1.2,
    frequency=100)
    

    }
model = prune.prune_low_magnitude(model, **pruning_params)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_conv2d_  (None, 28, 28, 90)       4952
#  12 (PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 14, 14, 90)       1
#  ling2d_12 (PruneLowMagnitud
#  e)
#
#  prune_low_magnitude_conv2d_  (None, 12, 12, 64)       103746
#  13 (PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 6, 6, 64)         1
#  ling2d_13 (PruneLowMagnitud
#  e)
#
#  prune_low_magnitude_conv2d_  (None, 4, 4, 32)         36898
#  14 (PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 2, 2, 32)         1
#  ling2d_14 (PruneLowMagnitud
#  e)
#
#  prune_low_magnitude_flatten  (None, 128)              1
#  _4 (PruneLowMagnitude)
#
#  prune_low_magnitude_dense_8  (None, 64)               16450
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_dense_9  (None, 3)                389
#   (PruneLowMagnitude)
#
# =================================================================
# Total params: 162,439
# Trainable params: 81,339
# Non-trainable params: 81,100
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam()
optimizer.learning_rate.assign(0.0008)

call = []
call.append(pruning_callbacks.UpdatePruningStep())
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy']
             )

# %%
epochs=14

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=call
)
model = strip_pruning(model)
# Out:
# Epoch 1/14
# 80/80 [==============================] - 5s 28ms/step - loss: 1.8601 - accuracy: 0.6983 - val_loss: 0.8864 - val_accuracy: 0.6156
# Epoch 2/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.1435 - accuracy: 0.9553 - val_loss: 0.7916 - val_accuracy: 0.6855
# Epoch 3/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.2108 - accuracy: 0.9284 - val_loss: 0.6268 - val_accuracy: 0.7285
# Epoch 4/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.1331 - accuracy: 0.9636 - val_loss: 0.7153 - val_accuracy: 0.6774
# Epoch 5/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.0704 - accuracy: 0.9842 - val_loss: 5.6911 - val_accuracy: 0.3333
# Epoch 6/14
# 80/80 [==============================] - 2s 26ms/step - loss: 0.4448 - accuracy: 0.8687 - val_loss: 0.9771 - val_accuracy: 0.6317
# Epoch 7/14
# 80/80 [==============================] - 2s 23ms/step - loss: 1.0005 - accuracy: 0.7948 - val_loss: 0.6641 - val_accuracy: 0.7258
# Epoch 8/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.4235 - accuracy: 0.8268 - val_loss: 0.7178 - val_accuracy: 0.6586
# Epoch 9/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.4891 - accuracy: 0.8213 - val_loss: 0.8517 - val_accuracy: 0.6747
# Epoch 10/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.4633 - accuracy: 0.8758 - val_loss: 0.6522 - val_accuracy: 0.8306
# Epoch 11/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.2835 - accuracy: 0.9498 - val_loss: 0.5935 - val_accuracy: 0.8656
# Epoch 12/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.1867 - accuracy: 0.9727 - val_loss: 0.5376 - val_accuracy: 0.8763
# Epoch 13/14
# 80/80 [==============================] - 2s 24ms/step - loss: 0.1276 - accuracy: 0.9854 - val_loss: 0.4924 - val_accuracy: 0.8387
# Epoch 14/14
# 80/80 [==============================] - 2s 25ms/step - loss: 0.0912 - accuracy: 0.9929 - val_loss: 0.4609 - val_accuracy: 0.8548

# %%
w = model.layers[0].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# % of zeros = 0.9

# %%
epochs=epochs
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 90)        2520
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 90)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 64)        51904
#
#  max_pooling2d_13 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 32)          18464
#
#  max_pooling2d_14 (MaxPoolin  (None, 2, 2, 32)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 81,339
# Trainable params: 81,339
# Non-trainable params: 0
# _________________________________________________________________
