# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from numpy.random import seed
import os
from imutils import paths
import random
import cv2
from sklearn import preprocessing
import tensorflow as tf
from matplotlib import pyplot
import qkeras
from qkeras import *
from qkeras.utils import model_save_quantized_weights

# %%
seed(0)
tf.random.set_seed(0)

# %%
#Enter the path of your image data folder
#image_data_folder_path = "./Datasheet_RPS/all_data/"
image_data_folder_path = "./custom_data/"


# initialize the data and labels as an empty list 
#we will reshape the image data and append it in the list-data
#we will encode the image labels and append it in the list-labels
data = []
labels = []

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(image_data_folder_path)))

#total number images
total_number_of_images = len(imagePaths)


#randomly shuffle all the image file name 
random.shuffle(imagePaths)

# loop over the shuffled input images
for imagePath in imagePaths:

    #Read the image into a numpy array using opencv
    #all the read images are of different shapes
    image = cv2.imread(imagePath)

    
    #resize the image to be 32x32 pixels (ignoring aspect ratio)
    #After reshape size of all the images will become 32x32x3
    #Total number of pixels in every image = 32x32x3=3072
    image = cv2.resize(image, (32, 32))
    
    img_float32 = np.float32(image)
    image_rgb = cv2.cvtColor(img_float32, cv2.COLOR_BGR2RGB)

    #flatten converts every 3D image (32x32x3) into 1D numpy array of shape (3072,)
    #(3072,) is the shape of the flatten image
    #(3072,) shape means 3072 columns and 1 row
    #image_flatten = image.flatten()

    #Append each image data 1D array to the data list
    data.append(image_rgb)

    # extract the class label from the image path and update the
    label = imagePath.split(os.path.sep)[-2]

    #Append each image label to the labels list
    labels.append(label)
# scale the raw pixel intensities to the range [0, 1]
#convert the data and label list to numpy array
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
# train_test_split is a scikit-learn's function which helps us to split train and test images kept in the same folders
(trainX, testX, trainY, testY) = train_test_split(data,labels, test_size=0.25, random_state=42)


# convert the labels from integers to vectors 
# perform One hot encoding of all the labels using scikit-learn's function LabelBinarizer
# LabelBinarizer fit_transform finds all the labels 
lb = preprocessing.LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

#trainX = trainX.reshape(trainX.shape[0], 32, 32, 3)
#testX = testX.reshape(testX.shape[0], 32, 32, 3)


print(np.shape(trainX))
print(np.shape(trainY))
print(np.shape(testX))
print(np.shape(testY))

randomint = np.random.randint(low = 1, high = 120)
img = (trainX[randomint, : ,: ,:])


pyplot.imshow(img)
# Out:
# (90, 32, 32, 3)
# (90, 3)
# (30, 32, 32, 3)
# (30, 3)

# %%
model = keras.Sequential()


model.add(qconvolutional.QConv2D(
    25, (3, 3), strides=(1,1),
    kernel_quantizer=quantized_bits(7,1),
    bias_quantizer=quantized_bits(7,1),
    name="conv2d1", input_shape = (32,32,3)))

model.add(QActivation(activation=quantized_relu(7), name='relu1'))

model.add(layers.MaxPool2D(pool_size=(1,1)))

model.add(qconvolutional.QConv2D(
    5, (3, 3), strides=(1,1),
    kernel_quantizer=quantized_bits(7,1),
    bias_quantizer=quantized_bits(7,1),
    name="conv2d2"))

model.add(QActivation(activation=quantized_relu(7), name='relu2'))

model.add(layers.MaxPool2D(pool_size=(1,1)))

model.add(layers.Flatten())

model.add(
    QDense(
        5,
        name='fc1',
        kernel_quantizer=quantized_bits(7, 1, alpha=1),
        bias_quantizer=quantized_bits(7, 1, alpha=1),
    ))
model.add(QActivation(activation=quantized_relu(7), name='relu3'))


model.add(
    QDense(
        3,
        name='fc2',
        kernel_quantizer=quantized_bits(7, 1, alpha=1),
        bias_quantizer=quantized_bits(7, 1, alpha=1),
    ))
model.add(layers.Activation(activations.softmax))

# %%
'''
model = keras.Sequential()

model.add(layers.Conv2D(25, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu', input_shape=(32,32,3)))
model.add(layers.MaxPool2D(pool_size=(1,1)))

model.add(layers.Conv2D(5, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))
model.add(layers.MaxPool2D(pool_size=(1,1)))

model.add(layers.Flatten())

model.add(layers.Dense(5, activation='relu'))

model.add(layers.Dense(3, activation='softmax'))

'''
# Out:
# "\nmodel = keras.Sequential()\n\nmodel.add(layers.Conv2D(25, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu', input_shape=(32,32,3)))\nmodel.add(layers.MaxPool2D(pool_size=(1,1)))\n\nmodel.add(layers.Conv2D(5, kernel_size=(3,3), strides=(1,1), padding='valid', activation='relu'))\nmodel.add(layers.MaxPool2D(pool_size=(1,1)))\n\nmodel.add(layers.Flatten())\n\nmodel.add(layers.Dense(5, activation='relu'))\n\nmodel.add(layers.Dense(3, activation='softmax'))\n\n"

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning, PruningSummaries

pruning_params = {

    "pruning_schedule": pruning_schedule.PolynomialDecay(
    initial_sparsity = 0,
    final_sparsity = .90,
    begin_step = 90,
    end_step = 1000,
    power=3,
    frequency=100)
    

    }
model = prune.prune_low_magnitude(model, **pruning_params)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_conv2d1  (None, 30, 30, 25)       1377
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_relu1 (  (None, 30, 30, 25)       1
#  PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 30, 30, 25)       1
#  ling2d_2 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_conv2d2  (None, 28, 28, 5)        2257
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_relu2 (  (None, 28, 28, 5)        1
#  PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 28, 28, 5)        1
#  ling2d_3 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_flatten  (None, 3920)             1
#  _1 (PruneLowMagnitude)
#
#  prune_low_magnitude_fc1 (Pr  (None, 5)                39207
#  uneLowMagnitude)
#
#  prune_low_magnitude_relu3 (  (None, 5)                1
#  PruneLowMagnitude)
#
#  prune_low_magnitude_fc2 (Pr  (None, 3)                35
#  uneLowMagnitude)
#
#  prune_low_magnitude_activat  (None, 3)                1
#  ion_1 (PruneLowMagnitude)
#
# =================================================================
# Total params: 42,883
# Trainable params: 21,453
# Non-trainable params: 21,430
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam()
optimizer.learning_rate.assign(0.0001)

call = []
call.append(pruning_callbacks.UpdatePruningStep())
call.append(tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=5,
    verbose=0,
    mode="min",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=35,
))

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy']
             )

# %%
# training the model
model.fit(trainX, trainY, batch_size=10, epochs=300 ,callbacks=call, validation_data=(testX, testY))
model = strip_pruning(model)
# Out:
# Epoch 1/300
# 9/9 [==============================] - 11s 238ms/step - loss: 1.1810 - accuracy: 0.3000 - val_loss: 1.0833 - val_accuracy: 0.4333
# Epoch 2/300
# 9/9 [==============================] - 0s 38ms/step - loss: 1.1005 - accuracy: 0.3000 - val_loss: 1.0861 - val_accuracy: 0.3333
# Epoch 3/300
# 9/9 [==============================] - 0s 35ms/step - loss: 1.0877 - accuracy: 0.2556 - val_loss: 1.0871 - val_accuracy: 0.4333
# Epoch 4/300
# 9/9 [==============================] - 0s 29ms/step - loss: 1.0865 - accuracy: 0.2778 - val_loss: 1.0816 - val_accuracy: 0.3667
# Epoch 5/300
# 9/9 [==============================] - 0s 29ms/step - loss: 1.0795 - accuracy: 0.3222 - val_loss: 1.0836 - val_accuracy: 0.3667
# Epoch 6/300
# 9/9 [==============================] - 0s 31ms/step - loss: 1.0806 - accuracy: 0.3444 - val_loss: 1.0862 - val_accuracy: 0.3333
# Epoch 7/300
# 9/9 [==============================] - 0s 35ms/step - loss: 1.0693 - accuracy: 0.3333 - val_loss: 1.0772 - val_accuracy: 0.4000
# Epoch 8/300
# 9/9 [==============================] - 0s 47ms/step - loss: 1.0662 - accuracy: 0.3000 - val_loss: 1.0830 - val_accuracy: 0.3667
# Epoch 9/300
# 9/9 [==============================] - 0s 39ms/step - loss: 1.0610 - accuracy: 0.3222 - val_loss: 1.0701 - val_accuracy: 0.3333
# Epoch 10/300
# 9/9 [==============================] - 0s 30ms/step - loss: 1.0548 - accuracy: 0.2778 - val_loss: 1.0684 - val_accuracy: 0.3333
# Epoch 11/300
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0501 - accuracy: 0.2889 - val_loss: 1.0690 - val_accuracy: 0.3333
# Epoch 12/300
# 9/9 [==============================] - 0s 29ms/step - loss: 1.0458 - accuracy: 0.3333 - val_loss: 1.0633 - val_accuracy: 0.3333
# Epoch 13/300
# 9/9 [==============================] - 0s 34ms/step - loss: 1.0406 - accuracy: 0.3222 - val_loss: 1.0601 - val_accuracy: 0.3667
# Epoch 14/300
# 9/9 [==============================] - 0s 27ms/step - loss: 1.0372 - accuracy: 0.3556 - val_loss: 1.0539 - val_accuracy: 0.3333
# Epoch 15/300
# 9/9 [==============================] - 0s 35ms/step - loss: 1.0375 - accuracy: 0.3444 - val_loss: 1.0484 - val_accuracy: 0.3333
# Epoch 16/300
# 9/9 [==============================] - 0s 45ms/step - loss: 1.0322 - accuracy: 0.3556 - val_loss: 1.0604 - val_accuracy: 0.4000
# Epoch 17/300
# 9/9 [==============================] - 0s 36ms/step - loss: 1.0344 - accuracy: 0.3222 - val_loss: 1.0455 - val_accuracy: 0.3667
# Epoch 18/300
# 9/9 [==============================] - 0s 32ms/step - loss: 1.0281 - accuracy: 0.3556 - val_loss: 1.0428 - val_accuracy: 0.4000
# Epoch 19/300
# 9/9 [==============================] - 0s 27ms/step - loss: 1.0165 - accuracy: 0.3556 - val_loss: 1.0355 - val_accuracy: 0.4333
# Epoch 20/300
# 9/9 [==============================] - 0s 28ms/step - loss: 1.0140 - accuracy: 0.3556 - val_loss: 1.0318 - val_accuracy: 0.4000
# Epoch 21/300
# 9/9 [==============================] - 0s 30ms/step - loss: 1.0101 - accuracy: 0.3778 - val_loss: 1.0284 - val_accuracy: 0.4333
# Epoch 22/300
# 9/9 [==============================] - 0s 26ms/step - loss: 1.0225 - accuracy: 0.3333 - val_loss: 1.0474 - val_accuracy: 0.3000
# Epoch 23/300
# 9/9 [==============================] - 0s 41ms/step - loss: 1.0354 - accuracy: 0.3778 - val_loss: 1.0405 - val_accuracy: 0.3667
# Epoch 24/300
# 9/9 [==============================] - 0s 41ms/step - loss: 1.0153 - accuracy: 0.3222 - val_loss: 1.0247 - val_accuracy: 0.3667
# Epoch 25/300
# 9/9 [==============================] - 0s 33ms/step - loss: 1.0181 - accuracy: 0.3444 - val_loss: 1.0185 - val_accuracy: 0.3333
# Epoch 26/300
# 9/9 [==============================] - 0s 35ms/step - loss: 1.0148 - accuracy: 0.3333 - val_loss: 1.0389 - val_accuracy: 0.4333
# Epoch 27/300
# 9/9 [==============================] - 0s 29ms/step - loss: 1.0197 - accuracy: 0.3111 - val_loss: 1.0196 - val_accuracy: 0.3667
# Epoch 28/300
# 9/9 [==============================] - 0s 30ms/step - loss: 0.9983 - accuracy: 0.3778 - val_loss: 1.0085 - val_accuracy: 0.3333
# Epoch 29/300
# 9/9 [==============================] - 0s 32ms/step - loss: 0.9943 - accuracy: 0.3556 - val_loss: 1.0064 - val_accuracy: 0.3667
# Epoch 30/300
# 9/9 [==============================] - 0s 24ms/step - loss: 1.0022 - accuracy: 0.3556 - val_loss: 1.0171 - val_accuracy: 0.3333
# Epoch 31/300
# 9/9 [==============================] - 0s 51ms/step - loss: 0.9916 - accuracy: 0.3556 - val_loss: 1.0069 - val_accuracy: 0.3667
# Epoch 32/300
# 9/9 [==============================] - 0s 32ms/step - loss: 0.9902 - accuracy: 0.4889 - val_loss: 1.0018 - val_accuracy: 0.5000
# Epoch 33/300
# 9/9 [==============================] - 0s 37ms/step - loss: 1.0943 - accuracy: 0.4000 - val_loss: 1.0189 - val_accuracy: 0.3000
# Epoch 34/300
# 9/9 [==============================] - 0s 34ms/step - loss: 1.0221 - accuracy: 0.5000 - val_loss: 1.0195 - val_accuracy: 0.4333
# Epoch 35/300
# 9/9 [==============================] - 0s 31ms/step - loss: 1.0327 - accuracy: 0.4778 - val_loss: 1.0157 - val_accuracy: 0.4667
# Epoch 36/300
# 9/9 [==============================] - 0s 32ms/step - loss: 1.0155 - accuracy: 0.4556 - val_loss: 1.0085 - val_accuracy: 0.5000
# Epoch 37/300
# 9/9 [==============================] - 0s 30ms/step - loss: 1.0080 - accuracy: 0.5556 - val_loss: 1.0205 - val_accuracy: 0.3000
# Epoch 38/300
# 9/9 [==============================] - 0s 25ms/step - loss: 1.0056 - accuracy: 0.4222 - val_loss: 0.9919 - val_accuracy: 0.4000
# Epoch 39/300
# 9/9 [==============================] - 1s 57ms/step - loss: 0.9979 - accuracy: 0.5556 - val_loss: 1.0065 - val_accuracy: 0.4000
# Epoch 40/300
# 9/9 [==============================] - 0s 31ms/step - loss: 0.9960 - accuracy: 0.5889 - val_loss: 0.9940 - val_accuracy: 0.4667
# Epoch 41/300
# 9/9 [==============================] - 0s 43ms/step - loss: 0.9885 - accuracy: 0.4889 - val_loss: 0.9949 - val_accuracy: 0.3667

# %%
w = model.layers[0].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# % of zeros = 0.4725925925925926

# %%
model.save("my_model.keras")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

y_predict = model.predict(testX)
print("Accuracy: {}".format(accuracy_score(np.argmax(testY, axis=1), np.argmax(y_predict, axis=1))))
plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(testY, y_predict, lb.classes_)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Accuracy: 0.5

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

confusion_matrix1 = metrics.confusion_matrix(np.argmax(testY, axis=1), np.argmax(y_predict, axis=1))

cm_display1 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix1)

cm_display1.plot()
plt.show()

# %%
trainp = model.predict(trainX)


confusion_matrix2 = metrics.confusion_matrix(np.argmax(trainY, axis=1), np.argmax(trainp, axis=1))

cm_display2 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix2)

cm_display2.plot()
plt.show()
# Out:
# 3/3 [==============================] - 0s 19ms/step
