# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from numpy.random import seed
import os
from imutils import paths
import random
import cv2
from sklearn import preprocessing
import tensorflow as tf
from matplotlib import pyplot
import qkeras
from qkeras import *
from qkeras.utils import model_save_quantized_weights

# %%
seed(0)
tf.random.set_seed(0)

# %%
#Enter the path of your image data folder
#image_data_folder_path = "./Datasheet_RPS/all_data/"
image_data_folder_path = "./custom_data/"


# initialize the data and labels as an empty list 
#we will reshape the image data and append it in the list-data
#we will encode the image labels and append it in the list-labels
data = []
labels = []

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(image_data_folder_path)))

#total number images
total_number_of_images = len(imagePaths)


#randomly shuffle all the image file name 
random.shuffle(imagePaths)

# loop over the shuffled input images
for imagePath in imagePaths:

    #Read the image into a numpy array using opencv
    #all the read images are of different shapes
    image = cv2.imread(imagePath)

    
    #resize the image to be 32x32 pixels (ignoring aspect ratio)
    #After reshape size of all the images will become 32x32x3
    #Total number of pixels in every image = 32x32x3=3072
    image = cv2.resize(image, (32, 32))
    
    img_float32 = np.float32(image)
    image_rgb = cv2.cvtColor(img_float32, cv2.COLOR_BGR2RGB)

    #flatten converts every 3D image (32x32x3) into 1D numpy array of shape (3072,)
    #(3072,) is the shape of the flatten image
    #(3072,) shape means 3072 columns and 1 row
    #image_flatten = image.flatten()

    #Append each image data 1D array to the data list
    data.append(image_rgb)

    # extract the class label from the image path and update the
    label = imagePath.split(os.path.sep)[-2]

    #Append each image label to the labels list
    labels.append(label)
# scale the raw pixel intensities to the range [0, 1]
#convert the data and label list to numpy array
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
# train_test_split is a scikit-learn's function which helps us to split train and test images kept in the same folders
(trainX, testX, trainY, testY) = train_test_split(data,labels, test_size=0.25, random_state=42)


# convert the labels from integers to vectors 
# perform One hot encoding of all the labels using scikit-learn's function LabelBinarizer
# LabelBinarizer fit_transform finds all the labels 
lb = preprocessing.LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

#trainX = trainX.reshape(trainX.shape[0], 32, 32, 3)
#testX = testX.reshape(testX.shape[0], 32, 32, 3)


print(np.shape(trainX))
print(np.shape(trainY))
print(np.shape(testX))
print(np.shape(testY))

randomint = np.random.randint(low = 1, high = 120)
img = (trainX[randomint, : ,: ,:])


pyplot.imshow(img)
# Out:
# (90, 32, 32, 3)
# (90, 3)
# (30, 32, 32, 3)
# (30, 3)

# %%
model = keras.Sequential()


model.add(qconvolutional.QConv2D(
    25, (3, 3), strides=(1,1),
    kernel_quantizer=quantized_bits(7,1),
    bias_quantizer=quantized_bits(7,1),
    name="conv2d1", input_shape = (32,32,3)))

model.add(QActivation(activation=quantized_relu(7), name='relu1'))

model.add(layers.MaxPool2D(pool_size=(1,1)))

model.add(qconvolutional.QConv2D(
    5, (3, 3), strides=(1,1),
    kernel_quantizer=quantized_bits(7,1),
    bias_quantizer=quantized_bits(7,1),
    name="conv2d2"))

model.add(QActivation(activation=quantized_relu(7), name='relu2'))

model.add(layers.MaxPool2D(pool_size=(1,1)))

model.add(layers.Flatten())

model.add(
    QDense(
        5,
        name='fc1',
        kernel_quantizer=quantized_bits(7, 1, alpha=1),
        bias_quantizer=quantized_bits(7, 1, alpha=1),
    ))
model.add(QActivation(activation=quantized_relu(7), name='relu3'))


model.add(
    QDense(
        3,
        name='fc2',
        kernel_quantizer=quantized_bits(7, 1, alpha=1),
        bias_quantizer=quantized_bits(7, 1, alpha=1),
    ))
model.add(layers.Activation(activations.softmax))

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning, PruningSummaries

pruning_params = {

    "pruning_schedule": pruning_schedule.PolynomialDecay(
    initial_sparsity = 0,
    final_sparsity = .90,
    begin_step = 100,
    end_step = 3000,
    power=1.5,
    frequency=100)
    

    }
model = prune.prune_low_magnitude(model, **pruning_params)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_conv2d1  (None, 30, 30, 25)       1377
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_relu1 (  (None, 30, 30, 25)       1
#  PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 30, 30, 25)       1
#  ling2d_6 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_conv2d2  (None, 28, 28, 5)        2257
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_relu2 (  (None, 28, 28, 5)        1
#  PruneLowMagnitude)
#
#  prune_low_magnitude_max_poo  (None, 28, 28, 5)        1
#  ling2d_7 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_flatten  (None, 3920)             1
#  _3 (PruneLowMagnitude)
#
#  prune_low_magnitude_fc1 (Pr  (None, 5)                39207
#  uneLowMagnitude)
#
#  prune_low_magnitude_relu3 (  (None, 5)                1
#  PruneLowMagnitude)
#
#  prune_low_magnitude_fc2 (Pr  (None, 3)                35
#  uneLowMagnitude)
#
#  prune_low_magnitude_activat  (None, 3)                1
#  ion_3 (PruneLowMagnitude)
#
# =================================================================
# Total params: 42,883
# Trainable params: 21,453
# Non-trainable params: 21,430
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam()
optimizer.learning_rate.assign(0.0005)

call = []
call.append(pruning_callbacks.UpdatePruningStep())
call.append(tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.05,
    patience=5,
    verbose=0,
    mode="min",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=400,
))

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy']
             )

# %%
# training the model
model.fit(trainX, trainY, batch_size=10, epochs=600 ,callbacks=call, validation_data=(testX, testY))
model = strip_pruning(model)
# Out:
# Epoch 1/600
# 9/9 [==============================] - 8s 180ms/step - loss: 1.1062 - accuracy: 0.3111 - val_loss: 1.1024 - val_accuracy: 0.3333
# Epoch 2/600
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0951 - accuracy: 0.3111 - val_loss: 1.0973 - val_accuracy: 0.3333
# Epoch 3/600
# 9/9 [==============================] - 0s 19ms/step - loss: 1.0897 - accuracy: 0.3667 - val_loss: 1.0906 - val_accuracy: 0.3667
# Epoch 4/600
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0725 - accuracy: 0.4111 - val_loss: 1.0922 - val_accuracy: 0.2333
# Epoch 5/600
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0434 - accuracy: 0.5667 - val_loss: 1.0997 - val_accuracy: 0.3000
# Epoch 6/600
# 9/9 [==============================] - 0s 21ms/step - loss: 1.0098 - accuracy: 0.6111 - val_loss: 1.0932 - val_accuracy: 0.2333
# Epoch 7/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.9395 - accuracy: 0.6000 - val_loss: 1.0729 - val_accuracy: 0.2667
# Epoch 8/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.8528 - accuracy: 0.6333 - val_loss: 1.0613 - val_accuracy: 0.3000
# Epoch 9/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.8211 - accuracy: 0.6111 - val_loss: 1.0926 - val_accuracy: 0.4000
# Epoch 10/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.7362 - accuracy: 0.7000 - val_loss: 1.0734 - val_accuracy: 0.2667
# Epoch 11/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6912 - accuracy: 0.6889 - val_loss: 1.0507 - val_accuracy: 0.3333
# Epoch 12/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6474 - accuracy: 0.6889 - val_loss: 1.1003 - val_accuracy: 0.3667
# Epoch 13/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6250 - accuracy: 0.7222 - val_loss: 1.0806 - val_accuracy: 0.3667
# Epoch 14/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5985 - accuracy: 0.7222 - val_loss: 1.0321 - val_accuracy: 0.4333
# Epoch 15/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5780 - accuracy: 0.7111 - val_loss: 1.0610 - val_accuracy: 0.4000
# Epoch 16/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5635 - accuracy: 0.7444 - val_loss: 1.0621 - val_accuracy: 0.4333
# Epoch 17/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5526 - accuracy: 0.7444 - val_loss: 1.0354 - val_accuracy: 0.4333
# Epoch 18/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5429 - accuracy: 0.7444 - val_loss: 1.0420 - val_accuracy: 0.4000
# Epoch 19/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5352 - accuracy: 0.7778 - val_loss: 1.0419 - val_accuracy: 0.4333
# Epoch 20/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5241 - accuracy: 0.8000 - val_loss: 1.0599 - val_accuracy: 0.4333
# Epoch 21/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5187 - accuracy: 0.7667 - val_loss: 1.0900 - val_accuracy: 0.4000
# Epoch 22/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5102 - accuracy: 0.7889 - val_loss: 1.0181 - val_accuracy: 0.4667
# Epoch 23/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5064 - accuracy: 0.8111 - val_loss: 1.0994 - val_accuracy: 0.4000
# Epoch 24/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4950 - accuracy: 0.7778 - val_loss: 1.0545 - val_accuracy: 0.4333
# Epoch 25/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4894 - accuracy: 0.8556 - val_loss: 1.0705 - val_accuracy: 0.4000
# Epoch 26/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4800 - accuracy: 0.8333 - val_loss: 1.0789 - val_accuracy: 0.3667
# Epoch 27/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4694 - accuracy: 0.9333 - val_loss: 1.0284 - val_accuracy: 0.4000
# Epoch 28/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4671 - accuracy: 0.9444 - val_loss: 1.1032 - val_accuracy: 0.4000
# Epoch 29/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4606 - accuracy: 0.9778 - val_loss: 1.0217 - val_accuracy: 0.4333
# Epoch 30/600
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4517 - accuracy: 0.9778 - val_loss: 1.0910 - val_accuracy: 0.4000
# Epoch 31/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4521 - accuracy: 0.9778 - val_loss: 1.0244 - val_accuracy: 0.4333
# Epoch 32/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4411 - accuracy: 1.0000 - val_loss: 1.0614 - val_accuracy: 0.4000
# Epoch 33/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4372 - accuracy: 0.9889 - val_loss: 1.0468 - val_accuracy: 0.4333
# Epoch 34/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4351 - accuracy: 1.0000 - val_loss: 1.0200 - val_accuracy: 0.4000
# Epoch 35/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4278 - accuracy: 1.0000 - val_loss: 1.0526 - val_accuracy: 0.4333
# Epoch 36/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4187 - accuracy: 1.0000 - val_loss: 1.0801 - val_accuracy: 0.4333
# Epoch 37/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4145 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.4000
# Epoch 38/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4084 - accuracy: 1.0000 - val_loss: 1.0553 - val_accuracy: 0.4000
# Epoch 39/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4048 - accuracy: 1.0000 - val_loss: 1.0472 - val_accuracy: 0.3667
# Epoch 40/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3993 - accuracy: 1.0000 - val_loss: 1.0331 - val_accuracy: 0.3667
# Epoch 41/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3943 - accuracy: 1.0000 - val_loss: 1.0401 - val_accuracy: 0.3667
# Epoch 42/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3921 - accuracy: 1.0000 - val_loss: 1.0322 - val_accuracy: 0.4000
# Epoch 43/600
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3862 - accuracy: 1.0000 - val_loss: 1.0129 - val_accuracy: 0.4000
# Epoch 44/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3846 - accuracy: 1.0000 - val_loss: 1.0502 - val_accuracy: 0.4000
# Epoch 45/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3831 - accuracy: 1.0000 - val_loss: 1.0177 - val_accuracy: 0.4333
# Epoch 46/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3802 - accuracy: 1.0000 - val_loss: 1.0178 - val_accuracy: 0.4667
# Epoch 47/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3757 - accuracy: 1.0000 - val_loss: 0.9927 - val_accuracy: 0.4667
# Epoch 48/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3711 - accuracy: 1.0000 - val_loss: 1.0193 - val_accuracy: 0.5000
# Epoch 49/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3652 - accuracy: 1.0000 - val_loss: 1.0417 - val_accuracy: 0.4667
# Epoch 50/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3622 - accuracy: 1.0000 - val_loss: 1.0255 - val_accuracy: 0.5333
# Epoch 51/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3589 - accuracy: 1.0000 - val_loss: 0.9948 - val_accuracy: 0.5667
# Epoch 52/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3545 - accuracy: 1.0000 - val_loss: 1.0431 - val_accuracy: 0.4667
# Epoch 53/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3527 - accuracy: 1.0000 - val_loss: 1.0314 - val_accuracy: 0.4667
# Epoch 54/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3504 - accuracy: 1.0000 - val_loss: 1.0061 - val_accuracy: 0.5667
# Epoch 55/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3426 - accuracy: 1.0000 - val_loss: 1.0668 - val_accuracy: 0.4333
# Epoch 56/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3342 - accuracy: 1.0000 - val_loss: 1.0540 - val_accuracy: 0.4667
# Epoch 57/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3215 - accuracy: 1.0000 - val_loss: 1.0669 - val_accuracy: 0.4667
# Epoch 58/600
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3215 - accuracy: 1.0000 - val_loss: 1.0822 - val_accuracy: 0.4333
# Epoch 59/600
# 9/9 [==============================] - 0s 34ms/step - loss: 0.3174 - accuracy: 1.0000 - val_loss: 1.0434 - val_accuracy: 0.5333
# Epoch 60/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3138 - accuracy: 1.0000 - val_loss: 1.0779 - val_accuracy: 0.4667
# Epoch 61/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3057 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.5000
# Epoch 62/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3028 - accuracy: 1.0000 - val_loss: 1.0469 - val_accuracy: 0.5333
# Epoch 63/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3007 - accuracy: 1.0000 - val_loss: 1.0864 - val_accuracy: 0.5333
# Epoch 64/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2988 - accuracy: 1.0000 - val_loss: 1.0678 - val_accuracy: 0.5000
# Epoch 65/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2987 - accuracy: 1.0000 - val_loss: 1.0559 - val_accuracy: 0.5333
# Epoch 66/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2979 - accuracy: 1.0000 - val_loss: 1.0721 - val_accuracy: 0.5333
# Epoch 67/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2963 - accuracy: 1.0000 - val_loss: 1.0297 - val_accuracy: 0.4667
# Epoch 68/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2954 - accuracy: 1.0000 - val_loss: 1.0629 - val_accuracy: 0.4667
# Epoch 69/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2859 - accuracy: 1.0000 - val_loss: 1.0694 - val_accuracy: 0.5667
# Epoch 70/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2832 - accuracy: 1.0000 - val_loss: 1.0583 - val_accuracy: 0.5333
# Epoch 71/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2820 - accuracy: 1.0000 - val_loss: 1.0959 - val_accuracy: 0.4667
# Epoch 72/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2805 - accuracy: 1.0000 - val_loss: 1.0659 - val_accuracy: 0.5333
# Epoch 73/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2782 - accuracy: 1.0000 - val_loss: 1.0498 - val_accuracy: 0.5333
# Epoch 74/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2763 - accuracy: 1.0000 - val_loss: 1.0657 - val_accuracy: 0.5000
# Epoch 75/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2759 - accuracy: 1.0000 - val_loss: 1.0844 - val_accuracy: 0.5333
# Epoch 76/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2736 - accuracy: 1.0000 - val_loss: 1.0434 - val_accuracy: 0.5667
# Epoch 77/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2694 - accuracy: 1.0000 - val_loss: 1.0591 - val_accuracy: 0.5333
# Epoch 78/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2846 - accuracy: 1.0000 - val_loss: 1.1628 - val_accuracy: 0.4000
# Epoch 79/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3020 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.5000
# Epoch 80/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3020 - accuracy: 1.0000 - val_loss: 1.1455 - val_accuracy: 0.4667
# Epoch 81/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3017 - accuracy: 1.0000 - val_loss: 1.1554 - val_accuracy: 0.4000
# Epoch 82/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3004 - accuracy: 1.0000 - val_loss: 1.1336 - val_accuracy: 0.4667
# Epoch 83/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2994 - accuracy: 1.0000 - val_loss: 1.1576 - val_accuracy: 0.4667
# Epoch 84/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2928 - accuracy: 1.0000 - val_loss: 1.1535 - val_accuracy: 0.4333
# Epoch 85/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2884 - accuracy: 1.0000 - val_loss: 1.1173 - val_accuracy: 0.5333
# Epoch 86/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2823 - accuracy: 1.0000 - val_loss: 1.1376 - val_accuracy: 0.4333
# Epoch 87/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2811 - accuracy: 1.0000 - val_loss: 1.1090 - val_accuracy: 0.5333
# Epoch 88/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2811 - accuracy: 1.0000 - val_loss: 1.1064 - val_accuracy: 0.5333
# Epoch 89/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3037 - accuracy: 0.9556 - val_loss: 0.9750 - val_accuracy: 0.5000
# Epoch 90/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3769 - accuracy: 1.0000 - val_loss: 1.0648 - val_accuracy: 0.4000
# Epoch 91/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3534 - accuracy: 0.9667 - val_loss: 0.9867 - val_accuracy: 0.4333
# Epoch 92/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3434 - accuracy: 1.0000 - val_loss: 1.0515 - val_accuracy: 0.4333
# Epoch 93/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3376 - accuracy: 1.0000 - val_loss: 1.0982 - val_accuracy: 0.4333
# Epoch 94/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3369 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.4333
# Epoch 95/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3359 - accuracy: 1.0000 - val_loss: 1.0411 - val_accuracy: 0.4333
# Epoch 96/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3321 - accuracy: 1.0000 - val_loss: 1.0221 - val_accuracy: 0.4667
# Epoch 97/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3273 - accuracy: 1.0000 - val_loss: 1.0543 - val_accuracy: 0.4667
# Epoch 98/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3232 - accuracy: 1.0000 - val_loss: 1.0464 - val_accuracy: 0.4333
# Epoch 99/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3214 - accuracy: 1.0000 - val_loss: 1.0441 - val_accuracy: 0.4667
# Epoch 100/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3162 - accuracy: 1.0000 - val_loss: 1.0431 - val_accuracy: 0.4667
# Epoch 101/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3178 - accuracy: 1.0000 - val_loss: 1.0777 - val_accuracy: 0.4000
# Epoch 102/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3142 - accuracy: 1.0000 - val_loss: 1.0819 - val_accuracy: 0.4000
# Epoch 103/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3146 - accuracy: 1.0000 - val_loss: 1.0652 - val_accuracy: 0.4000
# Epoch 104/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3086 - accuracy: 1.0000 - val_loss: 1.0476 - val_accuracy: 0.5000
# Epoch 105/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3072 - accuracy: 1.0000 - val_loss: 1.0575 - val_accuracy: 0.5000
# Epoch 106/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3035 - accuracy: 1.0000 - val_loss: 1.0815 - val_accuracy: 0.5333
# Epoch 107/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2972 - accuracy: 1.0000 - val_loss: 1.0378 - val_accuracy: 0.5000
# Epoch 108/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2950 - accuracy: 1.0000 - val_loss: 1.0542 - val_accuracy: 0.5000
# Epoch 109/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2947 - accuracy: 1.0000 - val_loss: 1.0915 - val_accuracy: 0.4667
# Epoch 110/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2947 - accuracy: 1.0000 - val_loss: 1.0749 - val_accuracy: 0.4000
# Epoch 111/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2907 - accuracy: 1.0000 - val_loss: 1.1210 - val_accuracy: 0.5000
# Epoch 112/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3856 - accuracy: 0.9667 - val_loss: 1.1155 - val_accuracy: 0.3667
# Epoch 113/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3156 - accuracy: 1.0000 - val_loss: 0.9489 - val_accuracy: 0.4667
# Epoch 114/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3004 - accuracy: 1.0000 - val_loss: 1.0392 - val_accuracy: 0.4667
# Epoch 115/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2860 - accuracy: 1.0000 - val_loss: 1.0525 - val_accuracy: 0.5000
# Epoch 116/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2778 - accuracy: 1.0000 - val_loss: 1.0084 - val_accuracy: 0.5000
# Epoch 117/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2751 - accuracy: 1.0000 - val_loss: 1.0492 - val_accuracy: 0.5000
# Epoch 118/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2723 - accuracy: 1.0000 - val_loss: 1.0170 - val_accuracy: 0.5000
# Epoch 119/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2704 - accuracy: 1.0000 - val_loss: 1.0099 - val_accuracy: 0.5000
# Epoch 120/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2696 - accuracy: 1.0000 - val_loss: 1.0268 - val_accuracy: 0.5000
# Epoch 121/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2687 - accuracy: 1.0000 - val_loss: 1.0466 - val_accuracy: 0.5000
# Epoch 122/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2665 - accuracy: 1.0000 - val_loss: 1.0669 - val_accuracy: 0.5000
# Epoch 123/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3034 - accuracy: 0.9778 - val_loss: 1.0396 - val_accuracy: 0.4333
# Epoch 124/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2886 - accuracy: 1.0000 - val_loss: 1.1561 - val_accuracy: 0.3667
# Epoch 125/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2686 - accuracy: 1.0000 - val_loss: 1.1021 - val_accuracy: 0.5000
# Epoch 126/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2619 - accuracy: 1.0000 - val_loss: 1.1151 - val_accuracy: 0.4667
# Epoch 127/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2580 - accuracy: 1.0000 - val_loss: 1.0474 - val_accuracy: 0.5333
# Epoch 128/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2552 - accuracy: 1.0000 - val_loss: 1.0540 - val_accuracy: 0.5333
# Epoch 129/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2540 - accuracy: 1.0000 - val_loss: 1.0723 - val_accuracy: 0.5333
# Epoch 130/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2523 - accuracy: 1.0000 - val_loss: 1.0692 - val_accuracy: 0.5333
# Epoch 131/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2514 - accuracy: 1.0000 - val_loss: 1.0677 - val_accuracy: 0.5333
# Epoch 132/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2514 - accuracy: 1.0000 - val_loss: 1.0805 - val_accuracy: 0.5333
# Epoch 133/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2500 - accuracy: 1.0000 - val_loss: 1.0724 - val_accuracy: 0.5333
# Epoch 134/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2720 - accuracy: 1.0000 - val_loss: 0.9866 - val_accuracy: 0.5667
# Epoch 135/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2693 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.6333
# Epoch 136/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2587 - accuracy: 1.0000 - val_loss: 0.9964 - val_accuracy: 0.5000
# Epoch 137/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2513 - accuracy: 1.0000 - val_loss: 1.0413 - val_accuracy: 0.5000
# Epoch 138/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2465 - accuracy: 1.0000 - val_loss: 1.0829 - val_accuracy: 0.4667
# Epoch 139/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2460 - accuracy: 1.0000 - val_loss: 1.0375 - val_accuracy: 0.5000
# Epoch 140/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2458 - accuracy: 1.0000 - val_loss: 1.0019 - val_accuracy: 0.5333
# Epoch 141/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2455 - accuracy: 1.0000 - val_loss: 1.0499 - val_accuracy: 0.5000
# Epoch 142/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2426 - accuracy: 1.0000 - val_loss: 1.0537 - val_accuracy: 0.5000
# Epoch 143/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2367 - accuracy: 1.0000 - val_loss: 1.0748 - val_accuracy: 0.4333
# Epoch 144/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2330 - accuracy: 1.0000 - val_loss: 1.0432 - val_accuracy: 0.4667
# Epoch 145/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3137 - accuracy: 0.9889 - val_loss: 0.9664 - val_accuracy: 0.6000
# Epoch 146/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2710 - accuracy: 1.0000 - val_loss: 0.9770 - val_accuracy: 0.5333
# Epoch 147/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2411 - accuracy: 1.0000 - val_loss: 0.9843 - val_accuracy: 0.4667
# Epoch 148/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.2352 - accuracy: 1.0000 - val_loss: 0.9562 - val_accuracy: 0.5333
# Epoch 149/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2297 - accuracy: 1.0000 - val_loss: 1.0045 - val_accuracy: 0.5333
# Epoch 150/600
# 9/9 [==============================] - 0s 26ms/step - loss: 0.2253 - accuracy: 1.0000 - val_loss: 1.0378 - val_accuracy: 0.5000
# Epoch 151/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2248 - accuracy: 1.0000 - val_loss: 1.0265 - val_accuracy: 0.5000
# Epoch 152/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2229 - accuracy: 1.0000 - val_loss: 1.0166 - val_accuracy: 0.5000
# Epoch 153/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2224 - accuracy: 1.0000 - val_loss: 1.0235 - val_accuracy: 0.5000
# Epoch 154/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2203 - accuracy: 1.0000 - val_loss: 1.0267 - val_accuracy: 0.5000
# Epoch 155/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2201 - accuracy: 1.0000 - val_loss: 1.0269 - val_accuracy: 0.5000
# Epoch 156/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3684 - accuracy: 0.9333 - val_loss: 1.0578 - val_accuracy: 0.4667
# Epoch 157/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3189 - accuracy: 1.0000 - val_loss: 1.0453 - val_accuracy: 0.5333
# Epoch 158/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2657 - accuracy: 1.0000 - val_loss: 1.0105 - val_accuracy: 0.5333
# Epoch 159/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2632 - accuracy: 1.0000 - val_loss: 1.0024 - val_accuracy: 0.5667
# Epoch 160/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2572 - accuracy: 1.0000 - val_loss: 1.0360 - val_accuracy: 0.5000
# Epoch 161/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2541 - accuracy: 1.0000 - val_loss: 1.0572 - val_accuracy: 0.4333
# Epoch 162/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2507 - accuracy: 1.0000 - val_loss: 1.0594 - val_accuracy: 0.4333
# Epoch 163/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2485 - accuracy: 1.0000 - val_loss: 1.0601 - val_accuracy: 0.4333
# Epoch 164/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2485 - accuracy: 1.0000 - val_loss: 1.0614 - val_accuracy: 0.4333
# Epoch 165/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2476 - accuracy: 1.0000 - val_loss: 1.0646 - val_accuracy: 0.4333
# Epoch 166/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2465 - accuracy: 1.0000 - val_loss: 1.0675 - val_accuracy: 0.4333
# Epoch 167/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3433 - accuracy: 0.9556 - val_loss: 0.9592 - val_accuracy: 0.5667
# Epoch 168/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3726 - accuracy: 1.0000 - val_loss: 1.1581 - val_accuracy: 0.4333
# Epoch 169/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2605 - accuracy: 1.0000 - val_loss: 0.9781 - val_accuracy: 0.4667
# Epoch 170/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2549 - accuracy: 1.0000 - val_loss: 1.0051 - val_accuracy: 0.5667
# Epoch 171/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2418 - accuracy: 1.0000 - val_loss: 1.0384 - val_accuracy: 0.5000
# Epoch 172/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2381 - accuracy: 1.0000 - val_loss: 1.0504 - val_accuracy: 0.5000
# Epoch 173/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2366 - accuracy: 1.0000 - val_loss: 1.0775 - val_accuracy: 0.5667
# Epoch 174/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2362 - accuracy: 1.0000 - val_loss: 1.0806 - val_accuracy: 0.5667
# Epoch 175/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2334 - accuracy: 1.0000 - val_loss: 1.0771 - val_accuracy: 0.5667
# Epoch 176/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2310 - accuracy: 1.0000 - val_loss: 1.0791 - val_accuracy: 0.5000
# Epoch 177/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2303 - accuracy: 1.0000 - val_loss: 1.0797 - val_accuracy: 0.5000
# Epoch 178/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2895 - accuracy: 0.9889 - val_loss: 0.9909 - val_accuracy: 0.4667
# Epoch 179/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2882 - accuracy: 1.0000 - val_loss: 1.2170 - val_accuracy: 0.3667
# Epoch 180/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2916 - accuracy: 1.0000 - val_loss: 1.2302 - val_accuracy: 0.4000
# Epoch 181/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2760 - accuracy: 1.0000 - val_loss: 1.2133 - val_accuracy: 0.4333
# Epoch 182/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2742 - accuracy: 1.0000 - val_loss: 1.2018 - val_accuracy: 0.4333
# Epoch 183/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2699 - accuracy: 1.0000 - val_loss: 1.1920 - val_accuracy: 0.4667
# Epoch 184/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2660 - accuracy: 1.0000 - val_loss: 1.1691 - val_accuracy: 0.4667
# Epoch 185/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2630 - accuracy: 1.0000 - val_loss: 1.1524 - val_accuracy: 0.4667
# Epoch 186/600
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2592 - accuracy: 1.0000 - val_loss: 1.1500 - val_accuracy: 0.4667
# Epoch 187/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2443 - accuracy: 1.0000 - val_loss: 1.1552 - val_accuracy: 0.4667
# Epoch 188/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2398 - accuracy: 1.0000 - val_loss: 1.1614 - val_accuracy: 0.4333
# Epoch 189/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2404 - accuracy: 1.0000 - val_loss: 1.2211 - val_accuracy: 0.3667
# Epoch 190/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2377 - accuracy: 1.0000 - val_loss: 1.1173 - val_accuracy: 0.4667
# Epoch 191/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2294 - accuracy: 1.0000 - val_loss: 1.1443 - val_accuracy: 0.4667
# Epoch 192/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2243 - accuracy: 1.0000 - val_loss: 1.1735 - val_accuracy: 0.4667
# Epoch 193/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2201 - accuracy: 1.0000 - val_loss: 1.1652 - val_accuracy: 0.4667
# Epoch 194/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2161 - accuracy: 1.0000 - val_loss: 1.1850 - val_accuracy: 0.4667
# Epoch 195/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2127 - accuracy: 1.0000 - val_loss: 1.1795 - val_accuracy: 0.4333
# Epoch 196/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2116 - accuracy: 1.0000 - val_loss: 1.1605 - val_accuracy: 0.4333
# Epoch 197/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2102 - accuracy: 1.0000 - val_loss: 1.1587 - val_accuracy: 0.4667
# Epoch 198/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2082 - accuracy: 1.0000 - val_loss: 1.1581 - val_accuracy: 0.4333
# Epoch 199/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2058 - accuracy: 1.0000 - val_loss: 1.1569 - val_accuracy: 0.5000
# Epoch 200/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2243 - accuracy: 1.0000 - val_loss: 1.0475 - val_accuracy: 0.5000
# Epoch 201/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2923 - accuracy: 1.0000 - val_loss: 1.1543 - val_accuracy: 0.4667
# Epoch 202/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2832 - accuracy: 1.0000 - val_loss: 1.0532 - val_accuracy: 0.5667
# Epoch 203/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2777 - accuracy: 1.0000 - val_loss: 1.0611 - val_accuracy: 0.4667
# Epoch 204/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2727 - accuracy: 1.0000 - val_loss: 1.0725 - val_accuracy: 0.5000
# Epoch 205/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2708 - accuracy: 1.0000 - val_loss: 1.0931 - val_accuracy: 0.5000
# Epoch 206/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2705 - accuracy: 1.0000 - val_loss: 1.1069 - val_accuracy: 0.4667
# Epoch 207/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2685 - accuracy: 1.0000 - val_loss: 1.1177 - val_accuracy: 0.5000
# Epoch 208/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2655 - accuracy: 1.0000 - val_loss: 1.1149 - val_accuracy: 0.5000
# Epoch 209/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2647 - accuracy: 1.0000 - val_loss: 1.1113 - val_accuracy: 0.5000
# Epoch 210/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2643 - accuracy: 1.0000 - val_loss: 1.1120 - val_accuracy: 0.5000
# Epoch 211/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2637 - accuracy: 1.0000 - val_loss: 1.1151 - val_accuracy: 0.5000
# Epoch 212/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3971 - accuracy: 0.9222 - val_loss: 1.0220 - val_accuracy: 0.4333
# Epoch 213/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2880 - accuracy: 1.0000 - val_loss: 0.9627 - val_accuracy: 0.5000
# Epoch 214/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2716 - accuracy: 1.0000 - val_loss: 0.9903 - val_accuracy: 0.5667
# Epoch 215/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2644 - accuracy: 1.0000 - val_loss: 1.0034 - val_accuracy: 0.6000
# Epoch 216/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2571 - accuracy: 1.0000 - val_loss: 1.0156 - val_accuracy: 0.5333
# Epoch 217/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2524 - accuracy: 1.0000 - val_loss: 1.0381 - val_accuracy: 0.5000
# Epoch 218/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2506 - accuracy: 1.0000 - val_loss: 1.0376 - val_accuracy: 0.5000
# Epoch 219/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2504 - accuracy: 1.0000 - val_loss: 1.0405 - val_accuracy: 0.4667
# Epoch 220/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2504 - accuracy: 1.0000 - val_loss: 1.0344 - val_accuracy: 0.5000
# Epoch 221/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2504 - accuracy: 1.0000 - val_loss: 1.0362 - val_accuracy: 0.4667
# Epoch 222/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2488 - accuracy: 1.0000 - val_loss: 1.0385 - val_accuracy: 0.4667
# Epoch 223/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4480 - accuracy: 0.9444 - val_loss: 0.8942 - val_accuracy: 0.6000
# Epoch 224/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3955 - accuracy: 1.0000 - val_loss: 1.0815 - val_accuracy: 0.5333
# Epoch 225/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3850 - accuracy: 1.0000 - val_loss: 1.0133 - val_accuracy: 0.5333
# Epoch 226/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3773 - accuracy: 1.0000 - val_loss: 0.9713 - val_accuracy: 0.5667
# Epoch 227/600
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3754 - accuracy: 1.0000 - val_loss: 0.9783 - val_accuracy: 0.5333
# Epoch 228/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3708 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.5000
# Epoch 229/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3700 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.5000
# Epoch 230/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3680 - accuracy: 1.0000 - val_loss: 1.0293 - val_accuracy: 0.5000
# Epoch 231/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3662 - accuracy: 1.0000 - val_loss: 1.0139 - val_accuracy: 0.5000
# Epoch 232/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3662 - accuracy: 1.0000 - val_loss: 1.0112 - val_accuracy: 0.5000
# Epoch 233/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3662 - accuracy: 1.0000 - val_loss: 1.0158 - val_accuracy: 0.5000
# Epoch 234/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6901 - accuracy: 0.6889 - val_loss: 0.8905 - val_accuracy: 0.6333
# Epoch 235/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4442 - accuracy: 1.0000 - val_loss: 1.0179 - val_accuracy: 0.4333
# Epoch 236/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4004 - accuracy: 0.9889 - val_loss: 0.9311 - val_accuracy: 0.5000
# Epoch 237/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3845 - accuracy: 1.0000 - val_loss: 0.9435 - val_accuracy: 0.4667
# Epoch 238/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3736 - accuracy: 1.0000 - val_loss: 0.9844 - val_accuracy: 0.5333
# Epoch 239/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3665 - accuracy: 1.0000 - val_loss: 0.9949 - val_accuracy: 0.5333
# Epoch 240/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3636 - accuracy: 1.0000 - val_loss: 0.9839 - val_accuracy: 0.5333
# Epoch 241/600
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3627 - accuracy: 1.0000 - val_loss: 0.9741 - val_accuracy: 0.5333
# Epoch 242/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3611 - accuracy: 1.0000 - val_loss: 0.9708 - val_accuracy: 0.5333
# Epoch 243/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3581 - accuracy: 1.0000 - val_loss: 1.0198 - val_accuracy: 0.5000
# Epoch 244/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3582 - accuracy: 1.0000 - val_loss: 0.9816 - val_accuracy: 0.5333
# Epoch 245/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.8002 - accuracy: 0.6889 - val_loss: 1.2943 - val_accuracy: 0.3667
# Epoch 246/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.8316 - accuracy: 0.6556 - val_loss: 1.3555 - val_accuracy: 0.3000
# Epoch 247/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.7693 - accuracy: 0.6778 - val_loss: 1.1376 - val_accuracy: 0.3333
# Epoch 248/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.7321 - accuracy: 0.7000 - val_loss: 1.2152 - val_accuracy: 0.3667
# Epoch 249/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4733 - accuracy: 0.9889 - val_loss: 1.0772 - val_accuracy: 0.4667
# Epoch 250/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4099 - accuracy: 0.9778 - val_loss: 0.9970 - val_accuracy: 0.5333
# Epoch 251/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3858 - accuracy: 1.0000 - val_loss: 0.9460 - val_accuracy: 0.5333
# Epoch 252/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3783 - accuracy: 1.0000 - val_loss: 0.9336 - val_accuracy: 0.6000
# Epoch 253/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3743 - accuracy: 1.0000 - val_loss: 0.9771 - val_accuracy: 0.5667
# Epoch 254/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3669 - accuracy: 1.0000 - val_loss: 0.9958 - val_accuracy: 0.6000
# Epoch 255/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3607 - accuracy: 1.0000 - val_loss: 0.9992 - val_accuracy: 0.5667
# Epoch 256/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6949 - accuracy: 0.7000 - val_loss: 1.0523 - val_accuracy: 0.4667
# Epoch 257/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.8154 - accuracy: 0.5667 - val_loss: 1.0633 - val_accuracy: 0.4667
# Epoch 258/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4870 - accuracy: 0.9444 - val_loss: 1.0548 - val_accuracy: 0.4000
# Epoch 259/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4380 - accuracy: 0.9889 - val_loss: 1.0504 - val_accuracy: 0.5000
# Epoch 260/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3835 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.5000
# Epoch 261/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3627 - accuracy: 1.0000 - val_loss: 1.0261 - val_accuracy: 0.4667
# Epoch 262/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3573 - accuracy: 1.0000 - val_loss: 0.9886 - val_accuracy: 0.5000
# Epoch 263/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3507 - accuracy: 1.0000 - val_loss: 1.0451 - val_accuracy: 0.4667
# Epoch 264/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3508 - accuracy: 1.0000 - val_loss: 0.9982 - val_accuracy: 0.5000
# Epoch 265/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3450 - accuracy: 1.0000 - val_loss: 1.0291 - val_accuracy: 0.5000
# Epoch 266/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3410 - accuracy: 1.0000 - val_loss: 1.0289 - val_accuracy: 0.5000
# Epoch 267/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5158 - accuracy: 0.8111 - val_loss: 0.9369 - val_accuracy: 0.5667
# Epoch 268/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4294 - accuracy: 0.9667 - val_loss: 1.0981 - val_accuracy: 0.3667
# Epoch 269/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3635 - accuracy: 1.0000 - val_loss: 0.9694 - val_accuracy: 0.4667
# Epoch 270/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3420 - accuracy: 1.0000 - val_loss: 0.9720 - val_accuracy: 0.4667
# Epoch 271/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3309 - accuracy: 1.0000 - val_loss: 1.0214 - val_accuracy: 0.5333
# Epoch 272/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3292 - accuracy: 1.0000 - val_loss: 1.0230 - val_accuracy: 0.5333
# Epoch 273/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3276 - accuracy: 1.0000 - val_loss: 1.0266 - val_accuracy: 0.5333
# Epoch 274/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3238 - accuracy: 1.0000 - val_loss: 1.0053 - val_accuracy: 0.5000
# Epoch 275/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3211 - accuracy: 1.0000 - val_loss: 1.0148 - val_accuracy: 0.5000
# Epoch 276/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3201 - accuracy: 1.0000 - val_loss: 1.0319 - val_accuracy: 0.5000
# Epoch 277/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3172 - accuracy: 1.0000 - val_loss: 1.0119 - val_accuracy: 0.5000
# Epoch 278/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5808 - accuracy: 0.8222 - val_loss: 1.4265 - val_accuracy: 0.3667
# Epoch 279/600
# 9/9 [==============================] - 0s 19ms/step - loss: 1.0259 - accuracy: 0.6222 - val_loss: 1.4270 - val_accuracy: 0.3000
# Epoch 280/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.9470 - accuracy: 0.6556 - val_loss: 1.3958 - val_accuracy: 0.3000
# Epoch 281/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.8793 - accuracy: 0.6556 - val_loss: 1.2988 - val_accuracy: 0.3333
# Epoch 282/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5919 - accuracy: 0.9333 - val_loss: 1.0244 - val_accuracy: 0.5333
# Epoch 283/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5603 - accuracy: 1.0000 - val_loss: 1.0496 - val_accuracy: 0.5333
# Epoch 284/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5214 - accuracy: 1.0000 - val_loss: 1.1396 - val_accuracy: 0.4667
# Epoch 285/600
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5143 - accuracy: 1.0000 - val_loss: 1.0873 - val_accuracy: 0.5333
# Epoch 286/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5093 - accuracy: 1.0000 - val_loss: 1.0469 - val_accuracy: 0.5333
# Epoch 287/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5106 - accuracy: 1.0000 - val_loss: 1.0979 - val_accuracy: 0.5333
# Epoch 288/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5068 - accuracy: 1.0000 - val_loss: 1.1115 - val_accuracy: 0.5000
# Epoch 289/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5767 - accuracy: 0.9333 - val_loss: 1.0159 - val_accuracy: 0.5667
# Epoch 290/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7757 - accuracy: 0.7333 - val_loss: 1.0640 - val_accuracy: 0.3333
# Epoch 291/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7104 - accuracy: 0.8222 - val_loss: 0.9916 - val_accuracy: 0.5000
# Epoch 292/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6601 - accuracy: 0.8444 - val_loss: 0.9833 - val_accuracy: 0.4333
# Epoch 293/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6271 - accuracy: 0.8778 - val_loss: 0.9878 - val_accuracy: 0.4667
# Epoch 294/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6158 - accuracy: 0.9333 - val_loss: 0.9731 - val_accuracy: 0.5000
# Epoch 295/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5926 - accuracy: 0.9444 - val_loss: 0.9779 - val_accuracy: 0.5333
# Epoch 296/600
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5934 - accuracy: 0.9111 - val_loss: 0.9943 - val_accuracy: 0.5000
# Epoch 297/600
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5844 - accuracy: 0.9778 - val_loss: 0.9876 - val_accuracy: 0.5000
# Epoch 298/600
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5732 - accuracy: 0.9667 - val_loss: 0.9675 - val_accuracy: 0.5333
# Epoch 299/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5593 - accuracy: 0.9778 - val_loss: 0.9719 - val_accuracy: 0.5000
# Epoch 300/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5666 - accuracy: 0.9556 - val_loss: 1.3559 - val_accuracy: 0.3000
# Epoch 301/600
# 9/9 [==============================] - 0s 26ms/step - loss: 0.9278 - accuracy: 0.6556 - val_loss: 1.3062 - val_accuracy: 0.3000
# Epoch 302/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.9027 - accuracy: 0.6556 - val_loss: 1.3249 - val_accuracy: 0.2667
# Epoch 303/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.8911 - accuracy: 0.6667 - val_loss: 1.2827 - val_accuracy: 0.3000
# Epoch 304/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.8736 - accuracy: 0.6667 - val_loss: 1.2800 - val_accuracy: 0.3000
# Epoch 305/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.8526 - accuracy: 0.6778 - val_loss: 1.2643 - val_accuracy: 0.3333
# Epoch 306/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.7312 - accuracy: 0.7333 - val_loss: 1.0030 - val_accuracy: 0.5000
# Epoch 307/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5464 - accuracy: 0.9556 - val_loss: 0.9155 - val_accuracy: 0.6333
# Epoch 308/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5396 - accuracy: 0.9444 - val_loss: 0.9350 - val_accuracy: 0.5667
# Epoch 309/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5193 - accuracy: 0.9778 - val_loss: 0.9483 - val_accuracy: 0.5000
# Epoch 310/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5126 - accuracy: 0.9889 - val_loss: 0.9123 - val_accuracy: 0.6000
# Epoch 311/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5055 - accuracy: 1.0000 - val_loss: 0.9172 - val_accuracy: 0.6000
# Epoch 312/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.8712 - accuracy: 0.6000 - val_loss: 0.8789 - val_accuracy: 0.6000
# Epoch 313/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.7099 - accuracy: 0.8667 - val_loss: 0.9235 - val_accuracy: 0.5667
# Epoch 314/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6165 - accuracy: 0.9222 - val_loss: 1.0171 - val_accuracy: 0.4333
# Epoch 315/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5607 - accuracy: 0.9667 - val_loss: 0.9141 - val_accuracy: 0.5667
# Epoch 316/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5213 - accuracy: 1.0000 - val_loss: 0.8618 - val_accuracy: 0.6000
# Epoch 317/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5134 - accuracy: 0.9889 - val_loss: 0.8884 - val_accuracy: 0.5667
# Epoch 318/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5059 - accuracy: 0.9889 - val_loss: 0.8752 - val_accuracy: 0.5667
# Epoch 319/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5051 - accuracy: 1.0000 - val_loss: 0.9136 - val_accuracy: 0.5667
# Epoch 320/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4996 - accuracy: 1.0000 - val_loss: 0.9137 - val_accuracy: 0.5667
# Epoch 321/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4975 - accuracy: 1.0000 - val_loss: 0.9129 - val_accuracy: 0.5667
# Epoch 322/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4961 - accuracy: 1.0000 - val_loss: 0.9113 - val_accuracy: 0.5000
# Epoch 323/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5707 - accuracy: 0.9556 - val_loss: 0.9744 - val_accuracy: 0.5333
# Epoch 324/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5614 - accuracy: 1.0000 - val_loss: 1.0754 - val_accuracy: 0.4333
# Epoch 325/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5431 - accuracy: 0.9889 - val_loss: 0.9635 - val_accuracy: 0.5000
# Epoch 326/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5144 - accuracy: 1.0000 - val_loss: 1.0336 - val_accuracy: 0.4667
# Epoch 327/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5006 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.4667
# Epoch 328/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4949 - accuracy: 1.0000 - val_loss: 0.9846 - val_accuracy: 0.4667
# Epoch 329/600
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4905 - accuracy: 1.0000 - val_loss: 1.0022 - val_accuracy: 0.5000
# Epoch 330/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4888 - accuracy: 1.0000 - val_loss: 1.0041 - val_accuracy: 0.5000
# Epoch 331/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4880 - accuracy: 1.0000 - val_loss: 0.9937 - val_accuracy: 0.5000
# Epoch 332/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4864 - accuracy: 1.0000 - val_loss: 1.0029 - val_accuracy: 0.5000
# Epoch 333/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4865 - accuracy: 1.0000 - val_loss: 1.0044 - val_accuracy: 0.5333
# Epoch 334/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5208 - accuracy: 0.9444 - val_loss: 1.0494 - val_accuracy: 0.4667
# Epoch 335/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4947 - accuracy: 1.0000 - val_loss: 0.9489 - val_accuracy: 0.5333
# Epoch 336/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5005 - accuracy: 1.0000 - val_loss: 0.9328 - val_accuracy: 0.5333
# Epoch 337/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4898 - accuracy: 1.0000 - val_loss: 0.9640 - val_accuracy: 0.5000
# Epoch 338/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4909 - accuracy: 1.0000 - val_loss: 0.9734 - val_accuracy: 0.5333
# Epoch 339/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4850 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.5333
# Epoch 340/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4835 - accuracy: 1.0000 - val_loss: 0.9902 - val_accuracy: 0.5333
# Epoch 341/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4826 - accuracy: 1.0000 - val_loss: 0.9971 - val_accuracy: 0.5333
# Epoch 342/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4831 - accuracy: 1.0000 - val_loss: 0.9768 - val_accuracy: 0.5667
# Epoch 343/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4807 - accuracy: 1.0000 - val_loss: 0.9549 - val_accuracy: 0.5667
# Epoch 344/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4818 - accuracy: 1.0000 - val_loss: 0.9896 - val_accuracy: 0.5667
# Epoch 345/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4798 - accuracy: 1.0000 - val_loss: 0.9688 - val_accuracy: 0.5667
# Epoch 346/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4792 - accuracy: 1.0000 - val_loss: 0.9702 - val_accuracy: 0.5667
# Epoch 347/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4769 - accuracy: 1.0000 - val_loss: 0.9873 - val_accuracy: 0.5667
# Epoch 348/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4769 - accuracy: 1.0000 - val_loss: 0.9862 - val_accuracy: 0.5667
# Epoch 349/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4765 - accuracy: 1.0000 - val_loss: 0.9760 - val_accuracy: 0.5667
# Epoch 350/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4764 - accuracy: 1.0000 - val_loss: 0.9892 - val_accuracy: 0.5667
# Epoch 351/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4760 - accuracy: 1.0000 - val_loss: 0.9901 - val_accuracy: 0.5333
# Epoch 352/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4760 - accuracy: 1.0000 - val_loss: 0.9924 - val_accuracy: 0.5667
# Epoch 353/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4766 - accuracy: 1.0000 - val_loss: 0.9830 - val_accuracy: 0.5667
# Epoch 354/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4767 - accuracy: 1.0000 - val_loss: 0.9911 - val_accuracy: 0.5667
# Epoch 355/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4764 - accuracy: 1.0000 - val_loss: 0.9766 - val_accuracy: 0.5667
# Epoch 356/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4757 - accuracy: 1.0000 - val_loss: 0.9845 - val_accuracy: 0.5333
# Epoch 357/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4750 - accuracy: 1.0000 - val_loss: 0.9950 - val_accuracy: 0.5333
# Epoch 358/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4742 - accuracy: 1.0000 - val_loss: 0.9974 - val_accuracy: 0.5333
# Epoch 359/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4733 - accuracy: 1.0000 - val_loss: 0.9815 - val_accuracy: 0.5333
# Epoch 360/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4721 - accuracy: 1.0000 - val_loss: 0.9857 - val_accuracy: 0.5667
# Epoch 361/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4724 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.5333
# Epoch 362/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4719 - accuracy: 1.0000 - val_loss: 1.0080 - val_accuracy: 0.5333
# Epoch 363/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4717 - accuracy: 1.0000 - val_loss: 0.9897 - val_accuracy: 0.5667
# Epoch 364/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4717 - accuracy: 1.0000 - val_loss: 0.9871 - val_accuracy: 0.5667
# Epoch 365/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4717 - accuracy: 1.0000 - val_loss: 0.9977 - val_accuracy: 0.5333
# Epoch 366/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4717 - accuracy: 1.0000 - val_loss: 0.9999 - val_accuracy: 0.5000
# Epoch 367/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4723 - accuracy: 1.0000 - val_loss: 0.9951 - val_accuracy: 0.5333
# Epoch 368/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4716 - accuracy: 1.0000 - val_loss: 0.9890 - val_accuracy: 0.5333
# Epoch 369/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4717 - accuracy: 1.0000 - val_loss: 0.9923 - val_accuracy: 0.5333
# Epoch 370/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4713 - accuracy: 1.0000 - val_loss: 1.0029 - val_accuracy: 0.5333
# Epoch 371/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4716 - accuracy: 1.0000 - val_loss: 1.0026 - val_accuracy: 0.5000
# Epoch 372/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4712 - accuracy: 1.0000 - val_loss: 0.9996 - val_accuracy: 0.5000
# Epoch 373/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4712 - accuracy: 1.0000 - val_loss: 1.0011 - val_accuracy: 0.5000
# Epoch 374/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4703 - accuracy: 1.0000 - val_loss: 1.0034 - val_accuracy: 0.5000
# Epoch 375/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4697 - accuracy: 1.0000 - val_loss: 1.0012 - val_accuracy: 0.5000
# Epoch 376/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4701 - accuracy: 1.0000 - val_loss: 0.9997 - val_accuracy: 0.5000
# Epoch 377/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4697 - accuracy: 1.0000 - val_loss: 0.9920 - val_accuracy: 0.5000
# Epoch 378/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4686 - accuracy: 1.0000 - val_loss: 0.9948 - val_accuracy: 0.5000
# Epoch 379/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4687 - accuracy: 1.0000 - val_loss: 0.9960 - val_accuracy: 0.5000
# Epoch 380/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4685 - accuracy: 1.0000 - val_loss: 0.9939 - val_accuracy: 0.5333
# Epoch 381/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4687 - accuracy: 1.0000 - val_loss: 1.0027 - val_accuracy: 0.5333
# Epoch 382/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4685 - accuracy: 1.0000 - val_loss: 0.9909 - val_accuracy: 0.5333
# Epoch 383/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4690 - accuracy: 1.0000 - val_loss: 0.9920 - val_accuracy: 0.5333
# Epoch 384/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4689 - accuracy: 1.0000 - val_loss: 0.9908 - val_accuracy: 0.5333
# Epoch 385/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4686 - accuracy: 1.0000 - val_loss: 0.9933 - val_accuracy: 0.5000
# Epoch 386/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4686 - accuracy: 1.0000 - val_loss: 0.9944 - val_accuracy: 0.5333
# Epoch 387/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4690 - accuracy: 1.0000 - val_loss: 0.9922 - val_accuracy: 0.5333
# Epoch 388/600
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4684 - accuracy: 1.0000 - val_loss: 0.9975 - val_accuracy: 0.5333
# Epoch 389/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4684 - accuracy: 1.0000 - val_loss: 0.9882 - val_accuracy: 0.5333
# Epoch 390/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4684 - accuracy: 1.0000 - val_loss: 0.9914 - val_accuracy: 0.5333
# Epoch 391/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4679 - accuracy: 1.0000 - val_loss: 1.0023 - val_accuracy: 0.5333
# Epoch 392/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4673 - accuracy: 1.0000 - val_loss: 0.9954 - val_accuracy: 0.5333
# Epoch 393/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 0.9967 - val_accuracy: 0.5333
# Epoch 394/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 0.9977 - val_accuracy: 0.5333
# Epoch 395/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 1.0047 - val_accuracy: 0.5333
# Epoch 396/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4671 - accuracy: 1.0000 - val_loss: 1.0031 - val_accuracy: 0.5333
# Epoch 397/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 1.0016 - val_accuracy: 0.5333
# Epoch 398/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4673 - accuracy: 1.0000 - val_loss: 1.0001 - val_accuracy: 0.5333
# Epoch 399/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4671 - accuracy: 1.0000 - val_loss: 1.0005 - val_accuracy: 0.5333
# Epoch 400/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4671 - accuracy: 1.0000 - val_loss: 1.0041 - val_accuracy: 0.5000
# Epoch 401/600
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4673 - accuracy: 1.0000 - val_loss: 1.0018 - val_accuracy: 0.5333
# Epoch 402/600
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4671 - accuracy: 1.0000 - val_loss: 0.9960 - val_accuracy: 0.5333
# Epoch 403/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 0.9963 - val_accuracy: 0.5333
# Epoch 404/600
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4672 - accuracy: 1.0000 - val_loss: 1.0030 - val_accuracy: 0.5333
# Epoch 405/600
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4664 - accuracy: 1.0000 - val_loss: 0.9992 - val_accuracy: 0.5333
# Epoch 406/600
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4664 - accuracy: 1.0000 - val_loss: 1.0025 - val_accuracy: 0.5333

# %%
w = model.layers[0].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# % of zeros = 0.8992592592592593

# %%
model.save("my_model.keras")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

y_predict = model.predict(testX)
print("Accuracy: {}".format(accuracy_score(np.argmax(testY, axis=1), np.argmax(y_predict, axis=1))))
plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(testY, y_predict, lb.classes_)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Accuracy: 0.5333333333333333

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

confusion_matrix1 = metrics.confusion_matrix(np.argmax(testY, axis=1), np.argmax(y_predict, axis=1))

cm_display1 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix1)

cm_display1.plot()
plt.show()

# %%
trainp = model.predict(trainX)


confusion_matrix2 = metrics.confusion_matrix(np.argmax(trainY, axis=1), np.argmax(trainp, axis=1))

cm_display2 = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix2)

cm_display2.plot()
plt.show()
# Out:
# 3/3 [==============================] - 0s 13ms/step
